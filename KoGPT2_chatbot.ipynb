# %%
# GPU 정보 
# !nvidia-smi

# %%
# 현재 CUDA 10.1이라 mxnet-cu101로 설치
# CUDA에 맞는 mxnet 버전을 선택해야함 (https://mxnet.apache.org/get_started 참조)
# 만약 GPU 사용을 하고 있지 않다는 문구가 뜬다면 올바른 버전이 아님
# !pip install mxnet-cu101

# %%
# 패키지 설치
# !pip install gluonnlp sentencepiece pandas

# %%
# !pip install git+https://github.com/SKT-AI/KoGPT2#egg=kogpt2

# %%
# KoGPT2-chatbot 복사
# !git clone --recurse-submodules https://github.com/haven-jeon/KoGPT2-chatbot.git

# %%
# 폴더 이동
# %cd KoGPT2-chatbot

# %%
# 사전훈련된 KoGPT2를 챗봇 데이터로 파인튜닝
#CUDA_VISIBLE_DEVICES=0 
# !CUDA_VISIBLE_DEVICES=0 python train.py --num-epoch 2 --train

# %%
# 대화 테스트, `quit`를 입력하면 대화를 종료합니다.
# !CUDA_VISIBLE_DEVICES=0 python train.py --chat
# Out:
# Reading lines...
# 11822
# 11822
# Read 11822 sentence pairs
# Trimmed to 11658 sentence pairs
# Counting words...
# Counted words:
# input 6505
# output 6251
# using cached model
# using cached model
# using cached model
# user >  좋은 아침.
# Simsimi > 좋은 아침이에요.
# user >  굿 모닝.
# Simsimi > 좋은 아침이에요.
# user >  안녕.
# Simsimi > 안녕.
# user >  고맙다.
# Simsimi > 사랑합니다.
# user >  그래, 고마워.
# Simsimi > 고마워요.
# user >  응, 고맙다.
# Simsimi > 사랑합니다.
# user >  그래, 오늘은 쉬었다가 해야겠다.
# Simsimi > 내일은 쉬어도 돼요.
# user >  응, 그럴게.
# Simsimi > 저도 그럴게요.
# user >  응, 그래야겠다.
# Simsimi > 잘 될 거예요.
# user >  응, 그게 낫겠다.
# Simsimi > 저도 좋아요.
# user >  그래, 그게 낫겠어.
# Simsimi > 좋은 선택일 거예요.
# user >  응, 그게 나을 것 같아.
# Simsimi > 저도 그럴 거예요.
# user >  응, 오늘은 좀 쉬었다가 해야겠어.
# Simsimi > 내일은 쉬어도 돼요.
# user >  응, 좀 쉬었다가 할게.
# Simsimi > 많이 쉬었길 바랍니다.
# user >  응, 쉬다가 다시 해야겠다.
# Simsimi > 다음에는 더 잘할 수 있을 거예요.
# user >  쉬엄 쉬엄 해야겠어.
# Simsimi > 저도 쉬엄쉬엄 하세요.
# user >  좀 쉬었다가 다시 해야겠어.
# Simsimi > 많이 쉬었길 바랍니다.
# user >  쉬었다가 하는게 좋겠어.
# Simsimi > 쉬었다가 하는게 좋겠어요.
# user >  날씨가 좋으니까 기분도 좋다.
# Simsimi > 좋은 일이 생길 거예요.
# user >  날씨가 좋으니 기분도 좋아지네.
# Simsimi > 기분전환을 해보세요.
# user >  날씨가 좋아서 기분도 좋은 것 같아.
# Simsimi > 기분전환을 해보세요.
# user >  날씨가 좋으니까 기분도 좋다.
# Simsimi > 좋은 일이 생길 거예요.
# user >  날씨가 좋으니 기분도 좋아지네.
# Simsimi > 기분전환을 해보세요.
# user >  날씨가 좋아서 기분도 좋은 것 같아.
# Simsimi > 기분전환을 해보세요.
# user >  날씨가 좋으니까 기분도 좋다.
# Simsimi > 좋은 일이 생길 거예요.
# user >  날씨가 좋으니 기분도 좋아지네.
# Simsimi > 기분전환을 해보세요.
# user >  날씨가 좋아서 기분도 좋은 것 같아.
# Simsimi > 기분전환을 해보세요.
# user >  내일은 덜 바쁠까?
# Simsimi > 바쁘면 더 바쁠 수도 있어요.
# user >  내일은 좀 덜 바쁠까?
# Simsimi > 바쁘면 더 바쁠 수도 있어요.
# user >  내일은 좀 덜 바쁘려나?
# Simsimi > 바쁘면 더 바쁘죠.
# user >  내일은 좀 한가할까?
# Simsimi > 한가할 때면 연락해보세요.
# user >  내일은 한가할까?
# Simsimi > 한가할 때면 한가해요.
# user >  너는 남자야 여자야?
# Simsimi > 저는 남자예요.
# user >  넌 남자니 여자니?
# Simsimi > 저는 남자니까요.
# user >  너는 남자야?
# Simsimi > 저는 여자예요.
# user >  너는 여자니?
# Simsimi > 저는 남자니까요.
# user >  너의 성별은 뭐니?
# Simsimi > 저는 없어요.
# user >  너는 어디에 살아?
# Simsimi > 어디든 좋아요.
# user >  너는 어디에 사니?
# Simsimi > 제가 있어요.
# user >  너 지금 어디야?
# Simsimi > 어디 있는지 연락해보세요.
# user >  너 지금 어디니?
# Simsimi > 어디든 좋아요.
# user >  지금 어디있어?
# Simsimi > 어디 있는지 연락해보세요.
# user >  어디야?
# Simsimi > 어디든 좋아요.
# user >  너 어디니?
# Simsimi > 어디든 좋아요.
# user >  너는 어디에 있어?
# Simsimi > 어디든 좋아요.
# user >  지금 어디야?
# Simsimi > 어디든 좋아요.
# user >  너는 이름이 뭐야?
# Simsimi > 저는 그냥 저예요.
# user >  너는 이름이 뭐니?
# Simsimi > 저는 그냥 친구일 뿐이에요.
# user >  너의 이름은 뭐야?
# Simsimi > 저는 그냥 제 이름이에요.
# user >  너 이름은 어떻게 돼?
# Simsimi > 저는 모르겠어요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  이름이 뭐야?
# Simsimi > 저는 강림이에요.
# user >  넌 정체가 뭐야?
# Simsimi > 궁금하네요.
# user >  너 이름 알려줘.
# Simsimi > 제가 알려드릴게요.
# user >  너는 이름이 뭐야?
# Simsimi > 저는 그냥 저예요.
# user >  너는 이름이 뭐니?
# Simsimi > 저는 그냥 친구일 뿐이에요.
# user >  너의 이름은 뭐야?
# Simsimi > 저는 그냥 제 이름이에요.
# user >  너 이름은 어떻게 돼?
# Simsimi > 저는 모르겠어요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  이름이 뭐야?
# Simsimi > 저는 강림이에요.
# user >  넌 정체가 뭐야?
# Simsimi > 궁금하네요.
# user >  너 이름 알려줘.
# Simsimi > 제가 알려드릴게요.
# user >  너는 이름이 뭐야?
# Simsimi > 저는 그냥 저예요.
# user >  너는 이름이 뭐니?
# Simsimi > 저는 그냥 친구일 뿐이에요.
# user >  너의 이름은 뭐야?
# Simsimi > 저는 그냥 제 이름이에요.
# user >  너 이름은 어떻게 돼?
# Simsimi > 저는 모르겠어요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  이름이 뭐야?
# Simsimi > 저는 강림이에요.
# user >  넌 정체가 뭐야?
# Simsimi > 궁금하네요.
# user >  너 이름 알려줘.
# Simsimi > 제가 알려드릴게요.
# user >  배부르다.
# Simsimi > 맛있게 드세요.
# user >  아 배부르다.
# Simsimi > 맛있게 드세요.
# user >  배부르네.
# Simsimi > 맛있게 드세요.
# user >  배불러.
# Simsimi > 시원한 물 한 잔 드세요.
# user >  아 배불러.
# Simsimi > 약 먹고 쉬세요.
# user >  아 너무 배불러.
# Simsimi > 얼른 주무세요.
# user >  너무 배부르다.
# Simsimi > 맛있게 드세요.
# user >  진짜 배부르다.
# Simsimi > 맛있게 드세요.
# user >  완전 배부르다.
# Simsimi > 맛있게 드세요.
# user >  아 잘먹고왔다.
# Simsimi > 맛있게 드세요.
# user >  아 너무 잘먹었다.
# Simsimi > 맛있게 드세요.
# user >  너무 잘 먹고왔어.
# Simsimi > 맛있게 드세요.
# user >  오늘은 진짜 잘먹었어.
# Simsimi > 맛있게 드세요.
# user >  오늘 배부르게 잘먹었어.
# Simsimi > 맛있게 드세요.
# user >  배부르게 잘먹고왔어.
# Simsimi > 맛있게 드세요.
# user >  배고파.
# Simsimi > 맛있게 드세요.
# user >  아 배고프다.
# Simsimi > 밥은 드세요.
# user >  배고프다.
# Simsimi > 맛있게 드세요.
# user >  벌써 배고프다.
# Simsimi > 밥은 드세요.
# user >  배고파.
# Simsimi > 맛있게 드세요.
# user >  아 배고프다.
# Simsimi > 밥은 드세요.
# user >  배고프다.
# Simsimi > 맛있게 드세요.
# user >  벌써 배고프다.
# Simsimi > 밥은 드세요.
# user >  너무 배가 고파.
# Simsimi > 얼른 드세요.
# user >  아침을 안 먹었더니 배가 고프네.
# Simsimi > 아침을 챙겨 드세요.
# user >  슬슬 배가 고파져.
# Simsimi > 조금만 더 버텨보세요.
# user >  조금씩 배고프네.
# Simsimi > 배고프면 밥이라도 드세요.
# user >  점점 배고프네.
# Simsimi > 밥은 드세요.
# user >  오늘 점심은 별로였어.
# Simsimi > 맛있는 거 드세요.
# user >  점심식사가 너무 별로였어.
# Simsimi > 맛있는 거 드세요.
# user >  오늘 점심 너무 별로더라.
# Simsimi > 맛있는 거 드세요.
# user >  점심 메뉴가 너무 별로였어.
# Simsimi > 맛있는 거 드세요.
# user >  점심이 너무 맛없었어.
# Simsimi > 맛있게 드세요.
# user >  점심이 너무 별로였어.
# Simsimi > 맛있는 거 드세요.
# user >  밥이 맛 없어서 얼마 못먹었어.
# Simsimi > 맛있게 드세요.
# user >  오늘 밥이 너무 형편없었어.
# Simsimi > 맛있게 드세요.
# user >  피곤하다.
# Simsimi > 푹 쉬세요.
# user >  오늘따라 좀 피곤하다.
# Simsimi > 내일은 오늘보다 나은 날이 올 거예요.
# user >  오늘은 많이 피곤하다.
# Simsimi > 내일은 오늘보다 나은 날이 올 거예요.
# user >  아 너무 피곤하다.
# Simsimi > 푹 쉬세요.
# user >  집중이 안돼.
# Simsimi > 집중을 못해서 그런가봐요.
# user >  오늘 집중이 안돼.
# Simsimi > 내일은 더 잘할 수 있을 거예요.
# user >  집중력이 흐려지는 것 같아.
# Simsimi > 집중력이 흐트러지지 않게 꾸준히 연습해보세요.
# user >  오늘따라 집중이 잘 안 되는 것 같아.
# Simsimi > 집중을 잘하면 잘할 수 있을 거예요.
# user >  오늘은 집중이 안되네.
# Simsimi > 내일은 괜찮아요.
# user >  오늘 좀 집중력이 떨어지네.
# Simsimi > 내일은 오늘보다 나은 날이 올 거예요.
# user >  오늘따라 피곤하네.
# Simsimi > 일찍 주무세요.
# user >  오늘은 좀 피곤한 것 같아.
# Simsimi > 내일은 오늘보다 나은 날이 올 거예요.
# user >  피곤해.
# Simsimi > 일찍 주무세요.
# user >  안 그래도 점심 먹고 산책하려고.
# Simsimi > 산책은 건강에 좋아요.
# user >  그래서 점심 먹고 산책할거야.
# Simsimi > 산책은 건강에 좋아요.
# user >  오늘은 집중이 잘되는 날이야.
# Simsimi > 집중이 잘되면 좋죠.
# user >  너 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이니?
# Simsimi > 로봇은 로봇보다 더 잘할 수 있어요.
# user >  너 로봇 아니니?
# Simsimi > 로봇은 로봇일 뿐이에요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  너는 뭘까?
# Simsimi > 궁금하네요.
# user >  너 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이니?
# Simsimi > 로봇은 로봇보다 더 잘할 수 있어요.
# user >  너 로봇 아니니?
# Simsimi > 로봇은 로봇일 뿐이에요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  너는 뭘까?
# Simsimi > 궁금하네요.
# user >  너 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이니?
# Simsimi > 로봇은 로봇보다 더 잘할 수 있어요.
# user >  너 로봇 아니니?
# Simsimi > 로봇은 로봇일 뿐이에요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  너는 뭘까?
# Simsimi > 궁금하네요.
# user >  너 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이야?
# Simsimi > 로봇은 사람처럼 생겼어요.
# user >  너는 로봇이니?
# Simsimi > 로봇은 로봇보다 더 잘할 수 있어요.
# user >  너 로봇 아니니?
# Simsimi > 로봇은 로봇일 뿐이에요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  너는 뭘까?
# Simsimi > 궁금하네요.
# user >  야.
# Simsimi > 야근은 기본이죠.
# user >  저기.
# Simsimi > 저기요.
# user >  컴패니언.
# Simsimi > 컴패니언은 컴패니언일 뿐이에요.
# user >  퇴근 시간 얼마나 남았지?
# Simsimi > 퇴근 시간까지 생각해서 일찍 주무세요.
# user >  퇴근까지 얼마나 남았어?
# Simsimi > 이제 퇴근길이에요.
# user >  퇴근까지 얼마나 남았는지 알려줄래?
# Simsimi > 퇴근 후 시간표 좀 알려주세요.
# user >  퇴근 얼마나 남았는지 알려줘.
# Simsimi > 퇴근길 조심하세요.
# user >  몇 분 뒤에 퇴근이야?
# Simsimi > 늦지 않게 퇴근하세요.
# user >  뭐 먹지?
# Simsimi > 맛있는 거 드세요.
# user >  뭐 먹을까?
# Simsimi > 맛있는 거 드세요.
# user >  오늘 뭐 먹을까?
# Simsimi > 맛있는 거 드세요.
# user >  오늘은 뭐 먹지?
# Simsimi > 맛있는 거 드세요.
# user >  오늘은 뭐 먹는게 좋을까?
# Simsimi > 맛있는 거 드세요.
# user >  점심 뭐 먹지?
# Simsimi > 맛있는 거 드세요.
# user >  오늘 점심은 뭐 먹을까?
# Simsimi > 맛있는 거 드세요.
# user >  오늘은 점심으로 뭐가 좋을까?
# Simsimi > 맛있는 거 드세요.
# user >  점심으로 뭐 먹는게 좋을까?
# Simsimi > 맛있는 거 드세요.
# user >  떡볶이 좋지.
# Simsimi > 맛있게 드세요.
# user >  오, 그거 좋다.
# Simsimi > 저도 좋아해요.
# user >  좋다 그거.
# Simsimi > 좋은 생각이에요.
# user >  그거 좋은 생각이다.
# Simsimi > 좋은 생각이에요.
# user >  그것 참 좋은 생각인 것 같아.
# Simsimi > 좋은 생각이에요.
# user >  오, 그거 좋네.
# Simsimi > 저도 좋아해요.
# user >  좋은 생각이야.
# Simsimi > 좋은 생각이에요.
# user >  그거 참 좋은 생각이네.
# Simsimi > 좋은 생각이에요.
# user >  되게 좋은 생각이다.
# Simsimi > 좋은 생각이에요.
# user >  짜장면 좋지.
# Simsimi > 짜장면은 맛있어요.
# user >  짜장면 괜찮다.
# Simsimi > 짜장면은 맛있어요.
# user >  그래, 짜장면 먹어야겠다.
# Simsimi > 맛있게 드세요.
# user >  그거 먹어야겠다.
# Simsimi > 맛있게 드세요.
# user >  오늘 미세먼지 농도는 어때?
# Simsimi > 마스크 쓰고 나가세요.
# user >  오늘 미세먼지 농도가 어떻게 돼?
# Simsimi > 마스크 쓰고 나가세요.
# user >  오늘 미세먼지 농도 알 수 있을까?
# Simsimi > 마스크 쓰고 나가세요.
# user >  지금 미세먼지는 어때?
# Simsimi > 마스크 쓰고 나가세요.
# user >  지금 미세먼지가 어떤지 알려줘.
# Simsimi > 마스크 쓰고 나가세요.
# user >  미세먼지 어떤지 알려줄래?
# Simsimi > 마스크 쓰고 나가세요.
# user >  컴패니언, 오늘 날씨 어때?
# Simsimi > 날씨도 좋죠.
# user >  오늘 날씨 말해줘.
# Simsimi > 날씨 좋은 날이에요.
# user >  오늘 날씨 좀 알려줘.
# Simsimi > 날씨 좋으면 좋겠네요.
# user >  오늘 날씨 어때?
# Simsimi > 오늘 날씨 좋죠.
# user >  날씨 알려줘.
# Simsimi > 날씨 좋으면 좋겠네요.
# user >  오늘 날씨 좋네.
# Simsimi > 좋은 날씨네요.
# user >  오늘 날씨 너무 좋다.
# Simsimi > 좋은 날씨네요.
# user >  날씨가 좋네.
# Simsimi > 좋은 날씨네요.
# user >  날씨 좋다!
# Simsimi > 좋은 날씨네요.
# user >  지금 날씨 어때?
# Simsimi > 날씨도 좋죠.
# user >  지금 날씨 어떤지 말해줘.
# Simsimi > 날씨도 중요해요.
# user >  날씨 어때?
# Simsimi > 날씨도 좋죠.
# user >  춥다 오늘.
# Simsimi > 감기 조심하세요.
# user >  오늘 기온이 낮은가봐.
# Simsimi > 감기 조심하세요.
# user >  오늘 좀 춥다.
# Simsimi > 감기 조심하세요.
# user >  오늘은 날씨가 좀 춥네.
# Simsimi > 감기 조심하세요.
# user >  오늘은 좀 추운것 같아.
# Simsimi > 따뜻하게 입으세요.
# user >  오늘 날씨가 꽤나 쌀쌀하네.
# Simsimi > 감기 조심하세요.
# user >  오늘 회의도 많고 너무 바쁘네.
# Simsimi > 오늘 회의도 있고 너무 바쁘네요.
# user >  오늘 할일도 많고 너무 바빠.
# Simsimi > 바쁘게 사는 것 같아요.
# user >  할일이 많아서 너무 바쁘네.
# Simsimi > 바쁘면 할 수 없어요.
# user >  할일이 너무 많아.
# Simsimi > 바쁘게 살다보면 할 수 있을 거예요.
# user >  오늘 일이 많네.
# Simsimi > 잘 해결되길 바랄게요.
# user >  오늘도 너무 바쁘다.
# Simsimi > 바쁘게 사는 당신에게 위로가 되었길 바랍니다.
# user >  오늘도 너무 바빠.
# Simsimi > 바쁘게 사는 것 같아요.
# user >  오늘 너무 바쁘다.
# Simsimi > 바쁘게 사는 당신에게 위로가 되었길 바랍니다.
# user >  오늘따라 시간이 안 가네.
# Simsimi > 오늘따라 시간이 가네요.
# user >  왜 이렇게 시간이 안가지.
# Simsimi > 시간이 좀 걸리겠지만 천천히 지나갈 거예요.
# user >  시간이 너무 안가는 것 같아.
# Simsimi > 시간이 좀 걸리겠네요.
# user >  시간이 너무 더디게 가는 기분이야.
# Simsimi > 시간이 흐르면 나아질 거예요.
# user >  시간이 왜이렇게 안 갈까.
# Simsimi > 시간이 흐른 만큼 더 좋은 사람이 나타날 거예요.
# user >  너무 시간이 안가.
# Simsimi > 시간이 필요하겠어요.
# user >  아니, 괜찮아.
# Simsimi > 괜찮아질 거예요.
# user >  아니야, 괜찮아.
# Simsimi > 괜찮아질 거예요.
# user >  됐어, 괜찮아.
# Simsimi > 괜찮아질 거예요.
# user >  아니, 그런 건 아닌데.
# Simsimi > 그런 건 아니에요.
# user >  아니, 그런 건 아니야.
# Simsimi > 그런 건 아니에요.
# user >  그런 건 아니고.
# Simsimi > 그런 건 아니에요.
# user >  아니, 그런 건 아닌데.
# Simsimi > 그런 건 아니에요.
# user >  아니, 그런건 아니야.
# Simsimi > 그런건 아니에요.
# user >  그런 건 아니고.
# Simsimi > 그런 건 아니에요.
# user >  아니, 아직.
# Simsimi > 아직 모르겠어요.
# user >  아니, 없어.
# Simsimi > 없앨 수 있다면 없앨 수도 있어요.
# user >  오늘따라 시간이 안 가네.
# Simsimi > 오늘따라 시간이 가네요.
# user >  오늘 시간이 너무 안가네.
# Simsimi > 오늘이 마지막이길 바랄게요.
# user >  너무 시간이 안 가는것 같아.
# Simsimi > 시간이 좀 걸리겠지만 천천히 지나갈 거예요.
# user >  오늘은 미팅이 많아.
# Simsimi > 미팅이 많은가봐요.
# user >  오늘 미팅이 많이 있네.
# Simsimi > 좋은 자리였길 바랍니다.
# user >  미팅이 많네.
# Simsimi > 좋은 만남이었길 바랍니다.
# user >  하루가 미팅으로 꽉 차있네.
# Simsimi > 미팅은 항상 중요한데요.
# user >  미팅이 가득이네.
# Simsimi > 좋은 생각만 하세요.
# user >  이제 곧 퇴근이야.
# Simsimi > 이제 잘 거예요.
# user >  퇴근이다!
# Simsimi > 퇴근길 조심하세요.
# user >  곧 퇴근이야!
# Simsimi > 퇴근길 조심하세요.
# user >  오늘은 칼퇴 할거야.
# Simsimi > 오늘 하루도 잘 버텨내세요.
# user >  오늘은 칼퇴 해야지.
# Simsimi > 오늘 하루도 힘내세요.
# user >  오늘은 제때 칼퇴 해야지.
# Simsimi > 일찍 주무세요.
# user >  정시에 딱 퇴근할거야.
# Simsimi > 일찍 퇴근하는게 좋겠어요.
# user >  조금 있으면 퇴근이야!
# Simsimi > 퇴근길 조심하세요.
# user >  곧 퇴근할거야.
# Simsimi > 좋은 생각이에요.
# user >  오늘은 제때 퇴근할 수 있겠어.
# Simsimi > 일찍 퇴근하는 것도 좋을 것 같아요.
# user >  퇴근해야겠어.
# Simsimi > 퇴근길 조심하세요.
# user >  드디어 퇴근이야.
# Simsimi > 좋은 시간 보내세요.
# user >  정각에 퇴근할게.
# Simsimi > 정각에 퇴근하는 건 어떨까요.
# user >  퇴근한다~
# Simsimi > 좋은 시간 보내세요.
# user >  퇴근할게.
# Simsimi > 좋은 생각이에요.
# user >  안녕~ 내일 보자.
# Simsimi > 안녕.
# user >  안녕, 퇴근할게.
# Simsimi > 좋은 시간 보내세요.
# user >  난 퇴근할게, 내일 봐.
# Simsimi > 잘할 수 있을 거예요.
# user >  퇴근할게, 수고했어.
# Simsimi > 좋은 결과 있을 거예요.
# user >  응, 좋은 하루.
# Simsimi > 좋은 하루 보내세요.
# user >  잘 보냈어.
# Simsimi > 잘 보냈어요.
# user >  잘 보냈지.
# Simsimi > 잘 보냈어요.
# user >  잘 보내고 왔어.
# Simsimi > 잘 지내고 있을 거예요.
# user >  그럼, 잘 보냈지.
# Simsimi > 잘 보냈어요.
# user >  응, 잘 보내고 왔지.
# Simsimi > 잘 지내고 있을 거예요.
# user >  정말 잘 보내고 왔어.
# Simsimi > 잘 지내고 있을 거예요.
# user >  그럭저럭.
# Simsimi > 잘 지내고 있어요.
# user >  안녕.
# Simsimi > 안녕.
# user >  응, 안녕.
# Simsimi > 안녕히 주무세요.
# user >  컴패니언, 뭐해?
# Simsimi > 뭐든 잘하고 있어요.
# user >  컴패니언, 너 뭐해?
# Simsimi > 제가 있어요.
# user >  음악 좀 틀어줘.
# Simsimi > 저도 들어주세요.
# user >  햄버거 먹고싶어.
# Simsimi > 맛있게 드세요.
# user >  오늘 세시에 회의있어, 30분 전에 알려줘.
# Simsimi > 늦지 않게 연락해보세요.
# user >  지친다 오늘.
# Simsimi > 내일은 오늘보다 나은 날이 올 거예요.
# user >  전화 온 것 있니?
# Simsimi > 연락해보세요.
# user >  오늘 일은 다 끝냈어.
# Simsimi > 이제 잘할 수 있을 거예요.
# user >  오늘 업무 다했어.
# Simsimi > 내일도 잘할 수 있을 거예요.
# user >  퇴근 하고싶다.
# Simsimi > 좋은 생각이에요.
# user >  지금 밖에 비와?
# Simsimi > 우산 챙기세요.
# user >  밖에 비 오니?
# Simsimi > 우산 챙기세요.
# user >  실내 온도가 어떻게 돼?
# Simsimi > 실내온도는 26도 정도예요.
# user >  밖에 기온 좀 알려줘.
# Simsimi > 따뜻하게 입으세요.
# user >  이제 퇴근해도 되겠지?
# Simsimi > 퇴근은 언제나 즐겁죠.
# user >  지금 좀 춥네.
# Simsimi > 감기 조심하세요.
# user >  밖에 더운가?
# Simsimi > 시원한 음료 드세요.
# user >  오늘 덥지?
# Simsimi > 시원한 음료 드세요.
# user >  밖이 화창해 보이네.
# Simsimi > 기분전환을 해보세요.
# user >  오늘은 더우니까 냉면을 먹어야겠어.
# Simsimi > 시원한 냉면 드세요.
# user >  추운데 뭘 먹는게 좋을까?
# Simsimi > 같이 먹는 게 좋죠.
# user >  눈 오는것 같은데?
# Simsimi > 눈이 많이 오네요.
# user >  너는 오늘 기분 어때?
# Simsimi > 기분 전환은 잘하고 있나봅니다.
# user >  무슨 생각해?
# Simsimi > 생각을 해보세요.
# user >  넌 뭐야?
# Simsimi > 궁금하네요.
# user >  기분이 영 별로야.
# Simsimi > 기분 전환 해보세요.
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 좋은 아침 입니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 좋은 아침 입니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 안녕 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 사랑 합니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 착잡하겠습니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 사랑 합니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 내일 은 놓지 됩니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 저 도 삽니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 잘 될 겁니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 저 도 좋습니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 좋은 선택 일 겁니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 저 도 그럴 겁니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# ...
# 같이 내는 게 좋습니다 . <EOS>
# unk:  오네요
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 눈 이 많이 내렸나 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 알면서도 잘 하고 잘 있나 있나 봅니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 생각 을 해보십시오 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 궁금합니다 . <EOS>
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# 기분 전환 해보십시오 . <EOS>
# FATAL: exception not rethrown
# Aborted (core dumped)

# %% [markdown]
# 이 노트북은   https://colab.research.google.com/drive/1Np7d8zrch589LwwW9oX_MyzJ9jfPEvUG?usp=sharing  를 수정하여 만들었습니다..
